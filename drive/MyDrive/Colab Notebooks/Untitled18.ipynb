# %%
#import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
#

# %%
import pandas as pd

data = {
    "City": [
        "Mumbai", "Delhi", "Bangalore", "Chennai", "Kolkata", "Hyderabad", "Pune",
        "Ahmedabad", "Jaipur", "Lucknow",
        "Mumbai", "Delhi", "Bangalore", "Chennai", "Kolkata", "Hyderabad", "Pune",
        "Ahmedabad", "Jaipur", "Lucknow"
    ],
    "Temperature": [
        28, 35, 24, 32, 31, 30, 26, 34, 38, 34,
        29, 33, 25, 31, 29, 30, 27, 35, 37, 32
    ],
    "Humidity": [
        85, 45, 70, 80, 78, 65, 75, 50, 35, 55,
        82, 50, 82, 82, 80, 58, 77, 42, 38, 58
    ],
    "Wind_Speed": [
        15, 8, 12, 18, 14, 10, 13, 6, 7, 9,
        16, 9, 11, 17, 15, 11, 10, 8, 7, 10
    ],
    "Cloud_Cover": [
        90, 30, 65, 85, 75, 55, 70, 25, 20, 40,
        92, 35, 68, 88, 78, 58, 72, 28, 22, 45
    ],
    "Rainfall_mm": [
        120, 15, 65, 95, 85, 45, 75, 8, 5, 25,
        125, 20, 68, 98, 88, 48, 70, 10, 6, 28
    ]
}

df = pd.DataFrame(data)
print(df)
# Out:
#          City  Temperature  Humidity  Wind_Speed  Cloud_Cover  Rainfall_mm
# 0      Mumbai           28        85          15           90          120
# 1       Delhi           35        45           8           30           15
# 2   Bangalore           24        70          12           65           65
# 3     Chennai           32        80          18           85           95
# 4     Kolkata           31        78          14           75           85
# 5   Hyderabad           30        65          10           55           45
# 6        Pune           26        75          13           70           75
# 7   Ahmedabad           34        50           6           25            8
# 8      Jaipur           38        35           7           20            5
# 9     Lucknow           34        55           9           40           25
# 10     Mumbai           29        82          16           92          125
# ...

# %%
df.isnull().sum()
# Out:
# City           0
# Temperature    0
# Humidity       0
# Wind_Speed     0
# Cloud_Cover    0
# Rainfall_mm    0
# dtype: int64

# %%
correlation = df[['Temperature','Humidity','Wind_Speed','Cloud_Cover','Rainfall_mm']].corr()
display(correlation['Rainfall_mm'].sort_values(ascending=False))
# Out:
# Rainfall_mm    1.000000
# Cloud_Cover    0.985081
# Humidity       0.942535
# Wind_Speed     0.928313
# Temperature   -0.679680
# Name: Rainfall_mm, dtype: float64

# %%
sns.set_style('whitegrid')
sns.pairplot(df)

# %%
City_rainfall = df.groupby('City')['Rainfall_mm'].mean().sort_values(ascending=False)
sns.barplot(x=City_rainfall.index, y=City_rainfall)
plt.title('City wise Rainfall')
plt.xlabel('City')
plt.ylabel('Average Rainfall (mm)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
x = df[['Temperature','Humidity','Wind_Speed','Cloud_Cover']]
y = df['Rainfall_mm']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (14, 4)
# (6, 4)
# (14,)
# (6,)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
#

# %%
result = pd.DataFrame({'Actual':y_test,'Predicted':y_pred, 'Difference (mm)': y_test-y_pred})

print(result)
# Out:
#     Actual   Predicted  Difference (mm)
# 0      120  107.681235        12.318765
# 17      10   12.390702        -2.390702
# 15      48   61.873352       -13.873352
# 1       15   14.589328         0.410672
# 8        5    1.731247         3.268753
# 5       45   51.364566        -6.364566

# %%
mean_squared_error = mean_squared_error(y_test,y_pred)
r2_score = r2_score(y_test,y_pred)

# %%
new = pd.DataFrame({'Temperature':[35],'Humidity':[84],'Wind_Speed':[16],'Cloud_Cover':[45]})

# %%
display(new)
# Out:
#    Temperature  Humidity  Wind_Speed  Cloud_Cover
# 0           35        84          16           45

# %%
newrecord = model.predict(new)
print(newrecord)
# Out:
# [11.85541026]

# %%
# !git remote add origin https://github.com/Sanath-2002/RAINFALL-PREDICTION-USING-REGRESSION.git
# !git branch -M main
# !git push -u origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git remote add origin https://github.com/Sanath-2002/RAINFALL-PREDICTION-USING-REGRESSION.git
# !git branch -M main
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/Sanath-2002/RAINFALL-PREDICTION-USING-REGRESSION.git'

# %%
# !git add .
# Out:
# error: open("drive/MyDrive/Kerala Tourism.gdoc"): Operation not supported
# error: unable to index file 'drive/MyDrive/Kerala Tourism.gdoc'
# fatal: adding files failed

# %%
with open('.gitignore', 'w') as f:
    f.write('*.gdoc\n')
    f.write('*.gslides\n')
    f.write('*.ipynb_checkpoints/\n')
print('Created .gitignore file.')
# Out:
# Created .gitignore file.

# %%
# !git add .
# Out:
# error: open("drive/MyDrive/Untitled presentation.gslides"): Operation not supported
# error: unable to index file 'drive/MyDrive/Untitled presentation.gslides'
# fatal: adding files failed

# %%
# !git commit -m "Initial commit"

# %%
# !git remote add origin https://github.com/Sanath-2002/RAINFALL-PREDICTION-USING-REGRESSION.git
# !git branch -M main
# !git push -u origin main

# %%
# !git commit -m "Initial commit"

# %%
# !git remote add origin https://github.com/Sanath-2002/RAINFALL-PREDICTION-USING-REGRESSION.git
# !git branch -M main
# !git push -u origin main
